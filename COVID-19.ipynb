# %%
import bs4 as bs
from urllib import request
import pandas as pd
import matplotlib.pyplot as plt
import requests

page = requests.get('https://www.worldometers.info/coronavirus/')

soup = bs.BeautifulSoup(page.text, 'html.parser')
print(soup.title.text)
# print(soup.find_all('p'))

htmltable = soup.find_all('table', { 'id' : 'main_table_countries_today' })
df = pd.read_html(str(htmltable))[0]
# Out:
# Coronavirus Update (Live): 725,232 Cases and 34,034 Deaths from COVID-19 Virus Outbreak - Worldometer

# %%
df1 = df.iloc[25:50,:]
plt.bar(df1['Country,Other'],df1['TotalCases'], label = 'count')
plt.xticks(rotation = 90)
plt.legend()
plt.show()

# df[df['Country,Other']=='India']

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Madhur\Desktop\covid_time2703.csv')
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/18/20  3/19/20  3/20/20  3/21/20  \
# 0        0        0        0  ...       22       22       24       24
# 1        0        0        0  ...       59       64       70       76
# 2        0        0        0  ...       74       87       90      139
# 3        0        0        0  ...       39       53       75       88
# 4        0        0        0  ...        0        0        1        2
#
#    3/22/20  3/23/20  3/24/20  3/25/20  3/26/20  3/27/20
# 0       40       40       74       84       94      110
# 1       89      104      123      146      174      186
# 2      201      230      264      302      367      409
# 3      113      133      164      188      224      267
# 4        2        3        3        3        4        4
#
# [5 rows x 70 columns]

# %%
df = df[df['3/27/20']>100]
df = df.groupby('Country/Region').sum()
df.head()
# Out:
#                     Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan     33.0000  65.0000        0        0        0        0        0
# Albania         41.1533  20.1683        0        0        0        0        0
# Algeria         28.0339   1.6596        0        0        0        0        0
# Andorra         42.5063   1.5218        0        0        0        0        0
# Argentina      -38.4161 -63.6167        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  ...  3/18/20  3/19/20  3/20/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       22       22       24
# Albania               0        0        0  ...       59       64       70
# Algeria               0        0        0  ...       74       87       90
# Andorra               0        0        0  ...       39       53       75
# Argentina             0        0        0  ...       79       97      128
#
#                 3/21/20  3/22/20  3/23/20  3/24/20  3/25/20  3/26/20  3/27/20
# Country/Region
# Afghanistan          24       40       40       74       84       94      110
# Albania              76       89      104      123      146      174      186
# Algeria             139      201      230      264      302      367      409
# Andorra              88      113      133      164      188      224      267
# Argentina           158      266      301      387      387      502      589
#
# [5 rows x 68 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\Madhur\Desktop\covid_time2703.csv')

# df = df.groupby('Country/Region').sum()

df = df[df['3/27/20']>100]
x = df.iloc[:,1:2]
y = df.iloc[:,43:]

df1 = pd.concat([x,y],axis = 1)
l = df1['Country/Region'].unique()
df1 = df1.groupby('Country/Region').sum()
# df1 = df1[df1['3/27/20']>100]
# df1.set_index('Country/Region')
df1 = df1.T
# df1['Country/Region'] = df['Country/Region'][:-2]
# df1

for i in l:
    country = i
    plt.plot(df1.index,df1[country], label = '#Cases')
    plt.title(i)
    plt.xticks(rotation = 90)
    plt.tick_params(axis = 'both', which = 'major', labelsize = 8)
    plt.legend(loc="upper left")
    plt.show()

# %%
# l = [i for i in df['Country/Region']]
# l

# %%
# print(df)

# t = soup.find_all('table')
# t

# for i in htmltable:
#     td = i.find_all('td')
#     print(td.text)
    
# .find_all('tr')

# %%
# for i in htmltable:
#     for p in i.find_all('tr'):
#         print(p.text)


'''
import pandas as pd
l = []
df = pd.DataFrame()
for i in htmltable[0].find_all('tr'):
    print(i.text)
    print('******')
    l.append(i.text)
'''
# Out:
# "\nimport pandas as pd\nl = []\ndf = pd.DataFrame()\nfor i in htmltable[0].find_all('tr'):\n    print(i.text)\n    print('******')\n    l.append(i.text)\n"

# %%
'''data = []

import pandas as pd
df = pd.DataFrame()
# rows = htmltable.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele]) # Get rid of empty values
    print(row)
#     for i in row.find_all('tr')
    
#     cols = row.find_all('td')
#     for i in row:
#         cols = i.text.strip()
#         df.append(cols)


data
# df
'''
# Out:
# "data = []\n\nimport pandas as pd\ndf = pd.DataFrame()\n# rows = htmltable.find_all('tr')\nfor row in rows:\n    cols = row.find_all('td')\n    cols = [ele.text.strip() for ele in cols]\n    data.append([ele for ele in cols if ele]) # Get rid of empty values\n    print(row)\n#     for i in row.find_all('tr')\n    \n#     cols = row.find_all('td')\n#     for i in row:\n#         cols = i.text.strip()\n#         df.append(cols)\n\n\ndata\n# df\n"

# %%
rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele]) # Get rid of empty values

# %%
'''def tableDataText(table):    
    """Parses a html segment started with tag <table> followed 
    by multiple <tr> (table rows) and inner <td> (table data) tags. 
    It returns a list of rows with inner columns. 
    Accepts only one <th> (table header/data) in the first row.
    """
    def rowgetDataText(tr, coltag='td'): # td (data) or th (header)       
        return [td.get_text(strip=True) for td in tr.find_all(coltag)]  
    rows = []
    trs = table.find_all('tr')
    headerow = rowgetDataText(trs[0], 'th')
    if headerow: # if there is a header row include first
        rows.append(headerow)
        trs = trs[1:]
    for tr in trs: # for every table row
        rows.append(rowgetDataText(tr, 'td') ) # data row       
    return rows

list_table = tableDataText(htmltable)
'''
# Out:
# 'def tableDataText(table):    \n    """Parses a html segment started with tag <table> followed \n    by multiple <tr> (table rows) and inner <td> (table data) tags. \n    It returns a list of rows with inner columns. \n    Accepts only one <th> (table header/data) in the first row.\n    """\n    def rowgetDataText(tr, coltag=\'td\'): # td (data) or th (header)       \n        return [td.get_text(strip=True) for td in tr.find_all(coltag)]  \n    rows = []\n    trs = table.find_all(\'tr\')\n    headerow = rowgetDataText(trs[0], \'th\')\n    if headerow: # if there is a header row include first\n        rows.append(headerow)\n        trs = trs[1:]\n    for tr in trs: # for every table row\n        rows.append(rowgetDataText(tr, \'td\') ) # data row       \n    return rows\n\nlist_table = tableDataText(htmltable)\n'
